# %%
#第二題
import matplotlib.pyplot as plt
#data
a = [-3, -1, 0, 1, 4]
b = [6, 4, 2, 0, -8]
x = np.linspace(-5,5,5)
y = 5*x-2
# 製作figure  
fig = plt.figure()   

#圖表的設定
ax = fig.add_subplot(1, 1, 1)

ax.scatter(a, b, color='red')
plt.plot(x, y)
plt.show()

# %%
#第三題
a = [-3, -1, 0, 1, 4]
b = [6, 4, 2, 0, -8]
x = np.linspace(-5.5,5.5,5.5)
y = 27*x+55
# 製作figure  
fig = plt.figure()   

#圖表的設定
ax = fig.add_subplot(1,1,1)

ax.scatter(a, b, color='red')
plt.plot(x, y)
plt.show()

# %%
#第四題
a = [-3, -1, 0, 1, 4]
b = [6, 4, 2, 0, -8]
x = np.linspace(-5.5,5.5,5.5)
y = 1+2*x
# 製作figure  
fig = plt.figure()   
#圖表的設定
ax = fig.add_subplot(1,1,1)
ax.scatter(a, b, color='red')
plt.plot(x, y)
plt.show()

# %%
#第四題
a = [-3, -1, 0, 1, 4]
b = [6, 4, 2, 0, -8]
x = np.linspace(-6,6,6)
y = 0.91+-1.27*x
# 製作figure  
fig = plt.figure()   
#圖表的設定
ax = fig.add_subplot(1,1,1)
ax.scatter(a, b, color='red')
plt.plot(x, y)
plt.show()
